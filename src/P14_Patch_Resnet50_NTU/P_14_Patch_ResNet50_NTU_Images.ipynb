# %%
pip install pyheif
# Out:
# Requirement already satisfied: pyheif in /usr/local/lib/python3.12/dist-packages (0.8.0)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pyheif) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.0->pyheif) (2.23)

# %%
import os
import shutil
from google.colab import drive

# Remove existing directory if it exists
mount_point = '/content/drive'
if os.path.exists(mount_point):
    shutil.rmtree(mount_point)

# Create fresh directory
os.makedirs(mount_point)

# Now mount
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""
Recapture Detector (ResNet50) — Patch-based training (Fully fixed & complete)
Experiment 14 | Patch-based for local pattern detection | All outputs saved
Key fixes:
- Consistent shapes (224x224 for train/val during training)
- Multi-patch inference on hold-out test set for better accuracy
- All required files saved: confusion matrices (png + csv), reports, curves, history csv, TFLite, summary
- Prints number of images processed at key steps
- Duration printed
Modified: Reduced N_FOLDS to 3 for shorter runtime; checkpoints enable resume
"""

# Step 1: Imports
import os
import json
import random
import hashlib
import time
import sys
from pathlib import Path
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import applications, layers, models, callbacks
from PIL import Image
import pyheif
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight

# Step 2: Settings & Hyperparameters
EXPERIMENT = 14
DATA_ROOT = "/content/drive/MyDrive/NTU-Roselab-Dataset"
MERGED = "/content/merged_ntu"
OUTPUT_DIR = "/content/drive/MyDrive/Recapture_Photo_Detection/Resnet50/results"
SPLIT_DIR = "/content/drive/MyDrive/Recapture_Photo_Detection"
IMG_SIZE = 224
LARGE_SIZE = 256
BATCH_SIZE = 16
EPOCHS = 8
LEARNING_RATE = 1e-4
N_FOLDS = 3
MODEL_NAME = "Resnet50"
PREPROCESSING = "none"
DROPOUT_RATE = 0.4
SEED = 42
TRAIN_FRAC, TEST_FRAC = 0.85, 0.15
REPEAT_FACTOR = 4
NUM_TEST_PATCHES = 5

HYPERPARAMETERS = {
    "learning_rate": LEARNING_RATE,
    "batch_size": BATCH_SIZE,
    "optimizer": "Adam",
    "epochs": EPOCHS,
    "n_folds": N_FOLDS,
    "dropout_rate": DROPOUT_RATE,
    "large_size": LARGE_SIZE,
    "repeat_factor": REPEAT_FACTOR,
    "num_test_patches": NUM_TEST_PATCHES
}

# Step 3: Create directories
for p in [OUTPUT_DIR, f"{OUTPUT_DIR}/checkpoints", MERGED, SPLIT_DIR]:
    Path(p).mkdir(parents=True, exist_ok=True)

# Step 4: Image conversion utilities
def ensure_jpg_from_path(src_path: Path, dst_path: Path, quality=95):
    dst_path.parent.mkdir(parents=True, exist_ok=True)
    if dst_path.exists():
        return
    sfx = src_path.suffix.lower()
    try:
        if sfx in {".heic", ".heif"}:
            heif_file = pyheif.read(str(src_path))
            img = Image.frombytes(heif_file.mode, heif_file.size, heif_file.data,
                                  "raw", heif_file.mode, heif_file.stride)
            img = img.convert("RGB")
            img.save(dst_path, "JPEG", quality=quality)
        else:
            img = Image.open(src_path).convert("RGB")
            img.save(dst_path, "JPEG", quality=quality)
    except Exception as e:
        print(f"[WARN] Failed converting {src_path}: {e}")

def copy_or_convert_all(src_folder, dst_folder):
    cnt = 0
    src = Path(src_folder)
    dst = Path(dst_folder)
    if not src.exists():
        print(f"[INFO] Folder not found: {src_folder}")
        return 0
    for f in src.rglob("*.*"):
        if f.suffix.lower() in {".jpg", ".jpeg", ".png", ".heic", ".heif"}:
            stem = f.stem
            dst_path = dst / f"{stem}.jpg"
            ensure_jpg_from_path(f, dst_path)
            cnt += 1
    return cnt

# Step 5: Merge & convert images
print("\n--- MERGING & CONVERTING ---")
orig_src = Path(DATA_ROOT) / "originals"
recap_src = Path(DATA_ROOT) / "recaptures"

if not orig_src.exists() or not recap_src.exists():
    print(f"[ERROR] Expected folders not found:")
    print(f"   originals: {orig_src}")
    print(f"   recaptures: {recap_src}")
    sys.exit(1)

os.makedirs(f"{MERGED}/originals", exist_ok=True)
os.makedirs(f"{MERGED}/recaptures", exist_ok=True)

orig_cnt = copy_or_convert_all(orig_src, f"{MERGED}/originals")
recap_cnt = copy_or_convert_all(recap_src, f"{MERGED}/recaptures")
print(f"Converted originals: {orig_cnt} | recaptures: {recap_cnt}")

if orig_cnt + recap_cnt == 0:
    print("[ERROR] No images found or converted. Stopping pipeline.")
    sys.exit(1)

# Step 6: Collect paths
def get_paths(folder):
    return sorted([str(p) for p in Path(folder).glob("*.jpg")])

orig_paths = get_paths(f"{MERGED}/originals")
recap_paths = get_paths(f"{MERGED}/recaptures")
print(f"Final - Originals: {len(orig_paths)} | Recaptures: {len(recap_paths)}")

if len(orig_paths) + len(recap_paths) == 0:
    print("[ERROR] No JPG images after conversion. Stopping.")
    sys.exit(1)

print(f"[INFO] No. images processed (converted to JPG): Originals {len(orig_paths)}, Recaptures {len(recap_paths)}, Total {len(orig_paths)+len(recap_paths)}")

# Step 7: Shuffle and split
np.random.seed(SEED)
random.seed(SEED)
np.random.shuffle(orig_paths)
np.random.shuffle(recap_paths)

def split_list(lst, train_frac):
    n = len(lst)
    if n == 0:
        return [], []
    n_train = int(np.floor(train_frac * n))
    return lst[:n_train], lst[n_train:]

train_o, test_o = split_list(orig_paths, TRAIN_FRAC)
train_r, test_r = split_list(recap_paths, TRAIN_FRAC)

train_paths = train_o + train_r
test_paths = test_o + test_r
train_labels = [0] * len(train_o) + [1] * len(train_r)
test_labels = [0] * len(test_o) + [1] * len(test_r)

print(f"TRAIN → Original: {len(train_o)} | Recapture: {len(train_r)} | Total: {len(train_paths)}")
print(f"TEST  → Original: {len(test_o)} | Recapture: {len(test_r)} | Total: {len(test_paths)}")

if len(train_paths) == 0:
    print("[ERROR] No training images after split. Stopping.")
    sys.exit(1)

print(f"[INFO] Train images: {len(train_paths)} | Test images: {len(test_paths)}")

# Step 8: Assurance checks
assert len(set(train_paths) & set(test_paths)) == 0, "Overlap detected!"
print("No train/test overlap — GOOD.")

# Save split hashes
def path_hash(p): return hashlib.md5(p.encode()).hexdigest()
split_hashes = {
    'train_hashes': [path_hash(p) for p in sorted(train_paths)],
    'test_hashes': [path_hash(p) for p in sorted(test_paths)]
}
with open(f"{SPLIT_DIR}/split_hashes.json","w") as f:
    json.dump(split_hashes, f, indent=2)

# Step 9: Dataset characteristics
def device_count(paths):
    counts = {}
    for p in paths:
        stem = Path(p).stem
        device = stem.split('_')[0] if '_' in stem else 'unknown'
        counts[device] = counts.get(device, 0) + 1
    return counts

dataset_info = {
    'total_originals': len(orig_paths),
    'total_recaptures': len(recap_paths),
    'total_images': len(orig_paths)+len(recap_paths),
    'per_device_originals': device_count(orig_paths),
    'per_device_recaptures': device_count(recap_paths),
    'splits': {
        'train': {'originals': len(train_o), 'recaptures': len(train_r)},
        'test': {'originals': len(test_o), 'recaptures': len(test_r)}
    }
}
with open(f"{OUTPUT_DIR}/dataset_characteristics.json","w") as f:
    json.dump(dataset_info, f, indent=2)
pd.DataFrame([dataset_info]).to_csv(f"{OUTPUT_DIR}/dataset_characteristics.csv", index=False)
print("Saved dataset characteristics.")

# Step 10: Pipeline summary
pipeline_summary = {
    'experiment': f"Experiment - {EXPERIMENT}",
    'seed': SEED,
    'img_size': IMG_SIZE,
    'batch_size': BATCH_SIZE,
    'repeat_factor': REPEAT_FACTOR,
    'augmentation': ['random_flip_left_right','random_brightness(0.1)','random_contrast(0.9,1.1)'],
    'preprocessing': PREPROCESSING,
    'model': 'ResNet50(include_top=False) + GAP + Dropout(0.4) + Dense(128,relu) + Dense(1,sigmoid)',
    'optimizer': f'Adam({LEARNING_RATE})',
    'loss': 'binary_crossentropy',
    'metrics': ['accuracy'],
    'split': {'train_frac': TRAIN_FRAC, 'test_frac': TEST_FRAC},
    'hyperparameters': HYPERPARAMETERS
}
with open(f"{OUTPUT_DIR}/pipeline_summary.json","w") as f:
    json.dump(pipeline_summary, f, indent=2)
with open(f"{OUTPUT_DIR}/README_pipeline.md","w") as f:
    f.write("# Pipeline Summary\n\n")
    for k,v in pipeline_summary.items():
        f.write(f"- **{k}**: {v}\n")
print("Saved pipeline summary.")

# Step 11: TF Dataset helpers
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

def decode_and_resize(path, resize_size=LARGE_SIZE):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (resize_size, resize_size))
    return img

def augment(img):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, 0.1)
    img = tf.image.random_contrast(img, 0.9, 1.1)
    return img

@tf.function
def process_train(path_tensor, label):
    img = decode_and_resize(path_tensor)
    if tf.random.uniform(()) < 0.7:
        img = augment(img)
    img = tf.image.random_crop(img, (IMG_SIZE, IMG_SIZE, 3))
    img = tf.keras.applications.resnet50.preprocess_input(img)
    return img, label

@tf.function
def process_val_test(path_tensor, label):
    img = decode_and_resize(path_tensor)
    offset = (LARGE_SIZE - IMG_SIZE) // 2
    img = tf.image.crop_to_bounding_box(img, offset, offset, IMG_SIZE, IMG_SIZE)
    img = tf.keras.applications.resnet50.preprocess_input(img)
    return img, label

# Step 12: Test dataset
test_paths_tf = tf.constant(test_paths, dtype=tf.string)
test_labels_tf = tf.constant(test_labels, dtype=tf.int32)
test_ds = tf.data.Dataset.from_tensor_slices((test_paths_tf, test_labels_tf))
test_ds = test_ds.map(process_val_test, num_parallel_calls=tf.data.AUTOTUNE) \
                 .batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# Step 13: Class weights
unique_labels = np.unique(train_labels)
if len(unique_labels) == 1:
    print(f"[INFO] Only one class found. Using uniform weight.")
    class_weight_dict = {int(unique_labels[0]): 1.0}
else:
    weights = compute_class_weight('balanced', classes=unique_labels, y=train_labels)
    class_weight_dict = {int(k): float(v) for k, v in zip(unique_labels, weights)}
print(f"Class weights: {class_weight_dict}")

# Step 14: Cross-validation training
print("\n--- STARTING 3-FOLD CROSS-VALIDATION ---")
start_time = time.time()

EXPERIMENT_NAME = f"exp_{EXPERIMENT}_{MODEL_NAME}_patch"
skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=SEED)
fold_results = []
best_val_acc = 0.0
best_fold = 0
best_model = None

train_paths_np = np.array(train_paths)
train_labels_np = np.array(train_labels)

for fold_no, (subtrain_idx, val_idx) in enumerate(skf.split(train_paths_np, train_labels_np), 1):
    print(f"\n=== Fold {fold_no}/{N_FOLDS} ===")
    subtrain_paths = train_paths_np[subtrain_idx].tolist()
    subtrain_labels = train_labels_np[subtrain_idx].tolist()
    val_paths = train_paths_np[val_idx].tolist()
    val_labels = train_labels_np[val_idx].tolist()

    print(f"[INFO] Fold {fold_no} - Subtrain images: {len(subtrain_paths)} | Val images: {len(val_paths)}")

    # Training dataset
    train_ds = tf.data.Dataset.from_tensor_slices((tf.constant(subtrain_paths), tf.constant(subtrain_labels)))
    train_ds = train_ds.repeat(REPEAT_FACTOR) \
                       .shuffle(buffer_size=8000, seed=SEED, reshuffle_each_iteration=True) \
                       .map(process_train, num_parallel_calls=tf.data.AUTOTUNE) \
                       .batch(BATCH_SIZE) \
                       .prefetch(tf.data.AUTOTUNE)

    # Validation dataset (for fit)
    val_ds = tf.data.Dataset.from_tensor_slices((tf.constant(val_paths), tf.constant(val_labels)))
    val_ds = val_ds.map(process_val_test, num_parallel_calls=tf.data.AUTOTUNE) \
                   .batch(BATCH_SIZE) \
                   .prefetch(tf.data.AUTOTUNE)

    # Model
    base = applications.ResNet50(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
    base.trainable = True
    inputs = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(DROPOUT_RATE)(x)
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    model = models.Model(inputs, outputs)

    model.compile(optimizer=tf.keras.optimizers.Adam(LEARNING_RATE),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # Callbacks
    ckpt_path = f"{OUTPUT_DIR}/checkpoints/{EXPERIMENT_NAME}_fold{fold_no}.weights.h5"
    cp = callbacks.ModelCheckpoint(ckpt_path, save_best_only=True, save_weights_only=True,
                                   monitor='val_accuracy', mode='max', verbose=1)
    es = callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, verbose=1)
    lr_reduce = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

    if Path(ckpt_path).exists():
        print("Resuming from existing checkpoint...")
        model.load_weights(ckpt_path)

    # Train
    steps_per_epoch = max(1, (len(subtrain_paths) * REPEAT_FACTOR) // BATCH_SIZE)
    history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS,
                        steps_per_epoch=steps_per_epoch,
                        callbacks=[cp, es, lr_reduce],
                        class_weight=class_weight_dict,
                        verbose=1)

    # Save history CSV
    hist_df = pd.DataFrame(history.history)
    hist_df.to_csv(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_history.csv", index=False)

    # Save loss curves PNG
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss Curve'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.grid(True)
    plt.subplot(1,2,2)
    plt.plot(history.history['accuracy'], label='Train Acc')
    plt.plot(history.history['val_accuracy'], label='Val Acc')
    plt.title('Accuracy Curve'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.grid(True)
    plt.savefig(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_learning_curve.png", dpi=300, bbox_inches='tight')
    plt.close()
    print(f"Saved learning curves and history for fold {fold_no}.")

    # Multi-patch prediction
    def predict_multi_patch(paths, labels, model, num_patches=NUM_TEST_PATCHES):
        crops = [
            (0, 0),
            (0, LARGE_SIZE - IMG_SIZE),
            (LARGE_SIZE - IMG_SIZE, 0),
            (LARGE_SIZE - IMG_SIZE, LARGE_SIZE - IMG_SIZE),
            ((LARGE_SIZE - IMG_SIZE)//2, (LARGE_SIZE - IMG_SIZE)//2)
        ][:num_patches]
        y_true = []
        y_pred_probs = []
        for path, label in zip(paths, labels):
            img = decode_and_resize(tf.constant(path))
            img = tf.expand_dims(img, 0)
            probs = []
            for cy, cx in crops:
                patch = img[:, cy:cy+IMG_SIZE, cx:cx+IMG_SIZE, :]
                prob = float(model(patch, training=False)[0][0])
                probs.append(prob)
            avg_prob = np.mean(probs)
            y_true.append(label)
            y_pred_probs.append(avg_prob)
        y_pred = [1 if p > 0.5 else 0 for p in y_pred_probs]
        return np.array(y_true), np.array(y_pred)

    # Evaluate with multi-patch
    y_val_true, y_val_pred = predict_multi_patch(val_paths, val_labels, model)
    y_test_true, y_test_pred = predict_multi_patch(test_paths, test_labels, model)

    cm_val = confusion_matrix(y_val_true, y_val_pred)
    cm_test = confusion_matrix(y_test_true, y_test_pred)

    acc_val = round(np.sum(y_val_true == y_val_pred) / len(y_val_true), 2) if len(y_val_true) > 0 else 0.0
    acc_test = round(np.sum(y_test_true == y_test_pred) / len(y_test_true), 2) if len(y_test_true) > 0 else 0.0

    # Save confusion matrices PNG & CSV
    for split, cm, acc in [("val", cm_val, acc_val), ("test", cm_test, acc_test)]:
        plt.figure(figsize=(6,5))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                    xticklabels=['Original','Recaptured'], yticklabels=['Original','Recaptured'])
        plt.title(f"Fold {fold_no} {split.upper()} Confusion Matrix | Acc: {acc:.2f}")
        plt.savefig(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_cm_{split}.png", dpi=300, bbox_inches='tight')
        plt.close()
        pd.DataFrame(cm).to_csv(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_cm_{split}.csv", index=False)

    # Save reports CSV (rounded 2 dec)
    report_val = classification_report(y_val_true, y_val_pred, target_names=['Original','Recaptured'], output_dict=True, zero_division=0)
    report_test = classification_report(y_test_true, y_test_pred, target_names=['Original','Recaptured'], output_dict=True, zero_division=0)
    pd.DataFrame(report_val).transpose().round(2).to_csv(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_report_val.csv")
    pd.DataFrame(report_test).transpose().round(2).to_csv(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_report_test.csv")

    # Fold summary JSON
    fold_summary = {
        'fold': fold_no,
        'val_accuracy': acc_val,
        'test_accuracy': acc_test,
        'val_report': report_val,
        'test_report': report_test
    }
    with open(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_summary.json","w") as f:
        json.dump(fold_summary, f, indent=2)

    fold_results.append(fold_summary)

    if acc_val > best_val_acc:
        best_val_acc = acc_val
        best_fold = fold_no
        best_model = model

# Step 15: Average results & save overall summary
avg_val_acc = round(np.mean([f['val_accuracy'] for f in fold_results]), 2)
avg_test_acc = round(np.mean([f['test_accuracy'] for f in fold_results]), 2)
print(f"\nAverage Validation Accuracy: {avg_val_acc:.2f} | Average Test Accuracy: {avg_test_acc:.2f}")

avg_summary = {
    'experiment': EXPERIMENT_NAME,
    'avg_val_accuracy': avg_val_acc,
    'avg_test_accuracy': avg_test_acc,
    'fold_details': fold_results
}
with open(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_average_summary.json","w") as f:
    json.dump(avg_summary, f, indent=2)

# Step 16: Save best model & TFLite
if best_model:
    best_model_path = f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_best_fold{best_fold}.keras"
    best_model.save(best_model_path)
    print(f"Saved best model: {best_model_path}")

    converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite = converter.convert()
    tflite_path = f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_detector.tflite"
    Path(tflite_path).write_bytes(tflite)
    print(f"Saved TFLite model: {tflite_path}")

# Step 17: Duration
duration = time.time() - start_time
print(f"\nTotal duration till completion: {duration:.2f} seconds ({duration/60:.2f} minutes)")

print("\nALL DONE. Results saved to:", OUTPUT_DIR)
# Out:
# --- MERGING & CONVERTING ---
# Converted originals: 1200 | recaptures: 1199
# Final - Originals: 774 | Recaptures: 976
# [INFO] No. images processed (converted to JPG): Originals 774, Recaptures 976, Total 1750
# TRAIN → Original: 657 | Recapture: 829 | Total: 1486
# TEST  → Original: 117 | Recapture: 147 | Total: 264
# [INFO] Train images: 1486 | Test images: 264
# No train/test overlap — GOOD.
# Saved dataset characteristics.
# Saved pipeline summary.
# Class weights: {0: 1.1308980213089803, 1: 0.8962605548854041}
#
# --- STARTING 3-FOLD CROSS-VALIDATION ---
#
# === Fold 1/3 ===
# [INFO] Fold 1 - Subtrain images: 990 | Val images: 496
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Resuming from existing checkpoint...
# Epoch 1/8
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 434 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9901 - loss: 0.0319
# Epoch 1: val_accuracy improved from -inf to 0.90121, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50/results/checkpoints/exp_14_Resnet50_patch_fold1.weights.h5
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 214s 600ms/step - accuracy: 0.9901 - loss: 0.0319 - val_accuracy: 0.9012 - val_loss: 0.5428 - learning_rate: 1.0000e-04
# Epoch 2/8
#   1/247 ━━━━━━━━━━━━━━━━━━━━ 2:10:51 32s/step - accuracy: 1.0000 - loss: 5.8597e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy did not improve from 0.90121
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 46s 58ms/step - accuracy: 1.0000 - loss: 5.8597e-04 - val_accuracy: 0.8992 - val_loss: 0.5291 - learning_rate: 1.0000e-04
# Epoch 3/8
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.9961 - loss: 0.0156
# Epoch 3: val_accuracy improved from 0.90121 to 0.92339, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50/results/checkpoints/exp_14_Resnet50_patch_fold1.weights.h5
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 140s 565ms/step - accuracy: 0.9961 - loss: 0.0157 - val_accuracy: 0.9234 - val_loss: 0.3581 - learning_rate: 1.0000e-04
# Epoch 4/8
#   1/247 ━━━━━━━━━━━━━━━━━━━━ 36s 148ms/step - accuracy: 0.8750 - loss: 0.0870
# Epoch 4: val_accuracy did not improve from 0.92339
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.8750 - loss: 0.0870 - val_accuracy: 0.9234 - val_loss: 0.3587 - learning_rate: 1.0000e-04
# Epoch 5/8
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.9923 - loss: 0.0187
# Epoch 5: val_accuracy did not improve from 0.92339
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 138s 558ms/step - accuracy: 0.9923 - loss: 0.0188 - val_accuracy: 0.8851 - val_loss: 0.5181 - learning_rate: 1.0000e-04
# Epoch 6/8
#   1/247 ━━━━━━━━━━━━━━━━━━━━ 36s 147ms/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 6: val_accuracy did not improve from 0.92339
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8871 - val_loss: 0.5540 - learning_rate: 1.0000e-04
# Epoch 7/8
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.9880 - loss: 0.0429
# Epoch 7: val_accuracy did not improve from 0.92339
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 135s 542ms/step - accuracy: 0.9879 - loss: 0.0429 - val_accuracy: 0.9214 - val_loss: 0.3606 - learning_rate: 1.0000e-04
# Epoch 8/8
#   1/247 ━━━━━━━━━━━━━━━━━━━━ 34s 140ms/step - accuracy: 1.0000 - loss: 0.0274
# Epoch 8: val_accuracy did not improve from 0.92339
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - accuracy: 1.0000 - loss: 0.0274 - val_accuracy: 0.9214 - val_loss: 0.3557 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 3.
# Saved learning curves and history for fold 1.
#
# === Fold 2/3 ===
# [INFO] Fold 2 - Subtrain images: 991 | Val images: 495
# Resuming from existing checkpoint...
# Epoch 1/8
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 434 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.9882 - loss: 0.0453
# Epoch 1: val_accuracy improved from -inf to 0.95152, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50/results/checkpoints/exp_14_Resnet50_patch_fold2.weights.h5
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 204s 588ms/step - accuracy: 0.9882 - loss: 0.0454 - val_accuracy: 0.9515 - val_loss: 0.3660 - learning_rate: 1.0000e-04
# Epoch 2/8
#   1/247 ━━━━━━━━━━━━━━━━━━━━ 2:11:28 32s/step - accuracy: 1.0000 - loss: 0.0038
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy improved from 0.95152 to 0.95556, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50/results/checkpoints/exp_14_Resnet50_patch_fold2.weights.h5
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 59s 110ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9556 - val_loss: 0.3604 - learning_rate: 1.0000e-04
# Epoch 3/8
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.9764 - loss: 0.0850
# Epoch 3: val_accuracy did not improve from 0.95556
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 148s 598ms/step - accuracy: 0.9764 - loss: 0.0850 - val_accuracy: 0.9515 - val_loss: 0.1650 - learning_rate: 1.0000e-04
# Epoch 4/8
#   1/247 ━━━━━━━━━━━━━━━━━━━━ 42s 171ms/step - accuracy: 1.0000 - loss: 0.0478
# Epoch 4: val_accuracy did not improve from 0.95556
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step - accuracy: 1.0000 - loss: 0.0478 - val_accuracy: 0.9515 - val_loss: 0.1674 - learning_rate: 1.0000e-04
# Epoch 5/8
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.9868 - loss: 0.0378
# Epoch 5: val_accuracy did not improve from 0.95556
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 145s 587ms/step - accuracy: 0.9868 - loss: 0.0378 - val_accuracy: 0.9212 - val_loss: 0.4059 - learning_rate: 1.0000e-04
# Epoch 6/8
#   1/247 ━━━━━━━━━━━━━━━━━━━━ 44s 180ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 6: val_accuracy did not improve from 0.95556
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9253 - val_loss: 0.4086 - learning_rate: 1.0000e-04
# Epoch 7/8
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.9913 - loss: 0.0236
# Epoch 7: val_accuracy did not improve from 0.95556
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 139s 563ms/step - accuracy: 0.9913 - loss: 0.0236 - val_accuracy: 0.8747 - val_loss: 0.5071 - learning_rate: 1.0000e-04
# Epoch 8/8
#   1/247 ━━━━━━━━━━━━━━━━━━━━ 44s 179ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 8: val_accuracy did not improve from 0.95556
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.8646 - val_loss: 0.6152 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 2.
# Saved learning curves and history for fold 2.
#
# === Fold 3/3 ===
# [INFO] Fold 3 - Subtrain images: 991 | Val images: 495
# Resuming from existing checkpoint...
# Epoch 1/8
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 434 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.9915 - loss: 0.0353
# Epoch 1: val_accuracy improved from -inf to 0.94747, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50/results/checkpoints/exp_14_Resnet50_patch_fold3.weights.h5
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 204s 582ms/step - accuracy: 0.9915 - loss: 0.0353 - val_accuracy: 0.9475 - val_loss: 0.1960 - learning_rate: 1.0000e-04
# Epoch 2/8
#   1/247 ━━━━━━━━━━━━━━━━━━━━ 2:02:19 30s/step - accuracy: 1.0000 - loss: 0.0026
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy did not improve from 0.94747
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 50s 84ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9475 - val_loss: 0.1945 - learning_rate: 1.0000e-04
# Epoch 3/8
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.9875 - loss: 0.0429
# Epoch 3: val_accuracy improved from 0.94747 to 0.95152, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50/results/checkpoints/exp_14_Resnet50_patch_fold3.weights.h5
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 145s 587ms/step - accuracy: 0.9875 - loss: 0.0429 - val_accuracy: 0.9515 - val_loss: 0.1846 - learning_rate: 1.0000e-04
# Epoch 4/8
#   1/247 ━━━━━━━━━━━━━━━━━━━━ 43s 177ms/step - accuracy: 1.0000 - loss: 0.0193
# Epoch 4: val_accuracy did not improve from 0.95152
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 1.0000 - loss: 0.0193 - val_accuracy: 0.9495 - val_loss: 0.1981 - learning_rate: 1.0000e-04
# Epoch 5/8
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9924 - loss: 0.0286
# Epoch 5: val_accuracy did not improve from 0.95152
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 136s 548ms/step - accuracy: 0.9924 - loss: 0.0285 - val_accuracy: 0.9172 - val_loss: 0.7025 - learning_rate: 1.0000e-04
# Epoch 6/8
#   1/247 ━━━━━━━━━━━━━━━━━━━━ 38s 158ms/step - accuracy: 1.0000 - loss: 9.3528e-04
# Epoch 6: val_accuracy did not improve from 0.95152
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 1.0000 - loss: 9.3528e-04 - val_accuracy: 0.8970 - val_loss: 0.8768 - learning_rate: 1.0000e-04
# Epoch 7/8
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9835 - loss: 0.0582
# Epoch 7: val_accuracy did not improve from 0.95152
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 136s 550ms/step - accuracy: 0.9835 - loss: 0.0582 - val_accuracy: 0.9293 - val_loss: 0.2021 - learning_rate: 1.0000e-04
# Epoch 8/8
#   1/247 ━━━━━━━━━━━━━━━━━━━━ 43s 178ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 8: val_accuracy did not improve from 0.95152
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 15s 60ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9293 - val_loss: 0.1982 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 3.
# Saved learning curves and history for fold 3.
#
# Average Validation Accuracy: 0.70 | Average Test Accuracy: 0.67
# Saved best model: /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50/results/exp_14_Resnet50_patch_best_fold2.keras
# Saved artifact at '/tmp/tmpykiz1hw9'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_356')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   135670341963408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135670341963024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135670343857552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135670341963216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135670343858128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135670341963600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782155728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782140752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782143824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782155920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782153040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782144592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782144784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782141904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782150352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782148240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782139984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782151120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782143248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782156112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135670341962832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135670343858512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135670343857744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782144400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135670343857360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135670343857936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782149968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782150544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782148816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782144208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782147664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782146128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782154384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782146896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782155344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782145744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782150160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782142480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782145360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782140176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782148432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782146704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782141712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782155536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782151504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782148624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782145552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782154000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782149776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782142672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782147472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782154192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782151312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782153616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782142864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782152848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782145936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782154576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782151696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782142096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782140368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782143056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782150928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782142288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782153424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782144976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782149392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782149008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782143440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782148048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782152464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782154768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782147856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782153232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780026832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780027984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782151888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780027408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782140944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780027600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782147088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782144016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782146320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782149200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782155152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667782141520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780026640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780029136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780028944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780026448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780028752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780027792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780027216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780030288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780030096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780028368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780029904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780029328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780028176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780031440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780031248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780029520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780031056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780030480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780028560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780032592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780032400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780030672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780032208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780031632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780029712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780033744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780033552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780031824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780033360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780032784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780030864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780034896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780034704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780032976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780034512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780033936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780032016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780036048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780035856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780034128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780035664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780035088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780033168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780037200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780037008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780035280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780036816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780036240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780034320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780038352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780038160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780036432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780037968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780037392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780035472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780039504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780039312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780037584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780040272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780039696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780037776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780041808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780041616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780039888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780041424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780042576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780040080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780038928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780042000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780041040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780040848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780042384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780039120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780038544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780036624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780040656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780040464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780038736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778699728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778700688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780041232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667780042192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778700112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778699344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778700496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778701840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778701648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778699536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778701456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778700880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778699920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778702992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778702800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778701072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778702608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778702032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778700304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778704144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778703952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778702224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778703760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778703184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778701264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778705296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778705104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778703376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778704912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778704336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778702416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778706448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778706256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778704528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778706064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778705488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778703568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778707600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778707408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778705680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778707216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778706640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778704720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778708752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778708560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778706832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778708368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778707792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778705872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778709904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778709712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778707984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778709520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778708944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778707024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778711056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778710864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778709136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778710672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778710096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778708176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778712208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778712016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778710288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778711824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778711248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778709328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778713360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778713168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778711440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778712976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778712400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778710480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778714512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778714320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778712592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778714128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778713552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778714896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778715088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778715472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778713744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778713936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778711632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778712784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779519696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778714704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667778715280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779518736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779519504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779519312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779520848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779520656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779519120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779521616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779521040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779518544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779523152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779522960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779521232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779522768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779522192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779520272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779524304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779524112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779522384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779523920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779523344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779520464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779519888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779518928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779522000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779521808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779520080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779521424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779525456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779525264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779523536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779525072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779524496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779522576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779526608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779526416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779524688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779526224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779525648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779523728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779527760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779527568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779525840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779527376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779526800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779524880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779528912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779528720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779526992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779528528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779527952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779526032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779530064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779529872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779528144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779529680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779529104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779527184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779531216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779531024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779529296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779530832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779530256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779528336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779532368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779532176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779530448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779532752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779532560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779533328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135667779529488: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved TFLite model: /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50/results/exp_14_Resnet50_patch_detector.tflite
#
# Total duration till completion: 5156.15 seconds (85.94 minutes)
#
# ALL DONE. Results saved to: /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50/results
