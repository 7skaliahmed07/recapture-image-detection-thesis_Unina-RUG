# %%
# --------------------------------------------------------------
# ROBUST RECAPTURE DETECTOR – 3 DEVICES, NO RECAPTURE BIAS
# --------------------------------------------------------------

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os, json, numpy as np, tensorflow as tf
from pathlib import Path
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import applications, layers, models, callbacks

# ---------- 0. SETTINGS ----------
MERGED_ROOT   = "/content/merged_dataset"
RESULTS_DIR   = "/content/drive/MyDrive/Merged_Model/results_final"
CHECKPOINT_DIR = f"{RESULTS_DIR}/checkpoints"
Path(RESULTS_DIR).mkdir(parents=True, exist_ok=True)
Path(CHECKPOINT_DIR).mkdir(parents=True, exist_ok=True)

# ---------- 1. LINK ALL IMAGES (flat) ----------
# !rm -rf {MERGED_ROOT}
os.makedirs(f"{MERGED_ROOT}/originals", exist_ok=True)
os.makedirs(f"{MERGED_ROOT}/recaptures", exist_ok=True)

def link_flat(src, dst, prefix=None):
    if not Path(src).exists(): return 0
    cnt = 0
    for img in Path(src).iterdir():
        if img.suffix.lower() in {".jpg",".jpeg",".png",".heic"}:
            name = f"{prefix}_{img.name}" if prefix else img.name
            dst_path = Path(dst) / name
            if not dst_path.exists():
                os.symlink(img, dst_path)
                cnt += 1
    return cnt

print("Linking 3 devices …")
devices = [
    ("NTU-Roselab-Dataset", None),
    ("Nothing_2a",          "nothing"),
    ("Poco-M3",             "poco")
]
for name, pref in devices:
    link_flat(f"/content/drive/MyDrive/{name}/originals",   f"{MERGED_ROOT}/originals",   pref)
    link_flat(f"/content/drive/MyDrive/{name}/recaptures",  f"{MERGED_ROOT}/recaptures",  pref)

# ---------- 2. SPLIT 80/20 (per class) ----------
def get_paths(folder, prefix=None):
    return [p for p in Path(folder).iterdir()
            if p.suffix.lower() in {".jpg",".jpeg",".png",".heic"}
            and (prefix is None or p.name.startswith(f"{prefix}_"))]

all_orig = get_paths(f"{MERGED_ROOT}/originals")
all_recp = get_paths(f"{MERGED_ROOT}/recaptures")

np.random.seed(42)
np.random.shuffle(all_orig); np.random.shuffle(all_recp)

train_orig = all_orig[:int(0.8*len(all_orig))]
val_orig   = all_orig[int(0.8*len(all_orig)):]
train_recp = all_recp[:int(0.8*len(all_recp))]
val_recp   = all_recp[int(0.8*len(all_recp)):]

print(f"TRAIN → Original {len(train_orig)} | Recaptured {len(train_recp)}")
print(f"VAL   → Original {len(val_orig)} | Recaptured {len(val_recp)}")

# ---------- 3. tf.data PIPELINES ----------
def decode(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = img[:, :, :3]
    img = tf.image.resize(img, (224, 224))
    return tf.keras.applications.efficientnet.preprocess_input(img)

def get_label(path):
    return tf.cast(tf.strings.split(path, os.sep)[-2] == "recaptures", tf.float32)

# ----- TRAIN (oversample *Original* 4×) -----
train_paths = [str(p) for p in train_orig + train_recp]
train_ds = tf.data.Dataset.from_tensor_slices(train_paths)
train_ds = train_ds.map(lambda p: (p, tf.strings.split(p, os.sep)[-1]))

orig_ds = train_ds.filter(lambda p, fn: ~tf.strings.regex_full_match(fn, ".*_.*"))
recp_ds = train_ds.filter(lambda p, fn:  tf.strings.regex_full_match(fn, ".*_.*"))

orig_ds = orig_ds.map(lambda p, _: (decode(p), get_label(p))).repeat(4).shuffle(2000)
recp_ds = recp_ds.map(lambda p, _: (decode(p), get_label(p)))

train_ds = orig_ds.concatenate(recp_ds).shuffle(4000).batch(16).prefetch(tf.data.AUTOTUNE)

# ----- VALIDATION -----
val_paths = [str(p) for p in val_orig + val_recp]
val_ds = tf.data.Dataset.from_tensor_slices(val_paths)
val_ds = val_ds.map(lambda p: (decode(p), get_label(p))).batch(32).prefetch(tf.data.AUTOTUNE)

# ---------- 4. MODEL (EfficientNetB0 – swap to ResNet50 below) ----------
inp = tf.keras.Input((224, 224, 3))
base = applications.EfficientNetB0(include_top=False, weights='imagenet')(inp)
# base = applications.ResNet50(include_top=False, weights='imagenet')(inp)   # <-- uncomment for ResNet50
x = layers.GlobalAveragePooling2D()(base)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.5)(x)
out = layers.Dense(1, activation='sigmoid')(x)
model = models.Model(inp, out)
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', 'Precision', 'Recall'])

# ---------- 5. CALLBACKS ----------
checkpoint_path = f"{CHECKPOINT_DIR}/cp-best.weights.h5"

cp_callback = callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor='val_f1_original',
    mode='max',
    save_best_only=True,
    verbose=1
)

class F1OriginalCallback(tf.keras.callbacks.Callback):
    def __init__(self, val_ds):
        super().__init__()
        self.val_ds = val_ds
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        y_true, y_pred = [], []
        for xb, yb in self.val_ds:
            pred = (self.model.predict(xb, verbose=0) > 0.5).astype(int)
            y_true.extend(yb.numpy())
            y_pred.extend(pred.flatten())
        f1 = classification_report(y_true, y_pred,
                                   target_names=['Original','Recaptured'],
                                   output_dict=True)['Original']['f1-score']
        logs['val_f1_original'] = f1
        print(f" — val_f1_original: {f1:.4f}")

f1_cb = F1OriginalCallback(val_ds)

early_stop = callbacks.EarlyStopping(
    monitor='val_f1_original',
    mode='max',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# RESUME
if os.path.exists(checkpoint_path):
    print("Resuming from checkpoint...")
    model.load_weights(checkpoint_path)

# ---------- 6. TRAIN ----------
print("\nStarting training (oversample Original)…")
model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    steps_per_epoch=250,
    callbacks=[cp_callback, f1_cb, early_stop],
    verbose=1
)

# ---------- 7. FINAL EVALUATION ----------
y_true, y_pred = [], []
for xb, yb in val_ds:
    pred = model.predict(xb, verbose=0)
    y_true.extend(yb.numpy())
    y_pred.extend((pred > 0.5).astype(int).flatten())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

cm = confusion_matrix(y_true, y_pred)
report = classification_report(y_true, y_pred,
                               target_names=['Original','Recaptured'],
                               output_dict=True)
acc = cm.diagonal().sum() / cm.sum()
f1_orig = report['Original']['f1-score']
f1_recp = report['Recaptured']['f1-score']

# ----- SAVE RESULTS (2 dp) -----
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Original','Recaptured'],
            yticklabels=['Original','Recaptured'])
plt.title(f'CM – Acc: {acc:.2%} | F1-Orig: {f1_orig:.2f}')
plt.ylabel('True'); plt.xlabel('Predicted')
plt.savefig(f"{RESULTS_DIR}/confusion_matrix.png", dpi=200, bbox_inches='tight')
plt.close()

df_rep = pd.DataFrame(report).transpose().round(2)
df_rep.to_csv(f"{RESULTS_DIR}/classification_report.csv")

metrics = {
    "val_accuracy": round(float(acc), 2),
    "f1_original": round(f1_orig, 2),
    "f1_recaptured": round(f1_recp, 2),
    "original_correct": int(cm[0,0]),
    "recaptured_correct": int(cm[1,1]),
    "total_samples": int(cm.sum())
}
with open(f"{RESULTS_DIR}/metrics_summary.json", 'w') as f:
    json.dump(metrics, f, indent=2)

print("\n" + "="*60)
print("FINAL RESULTS (2 dp)")
print(f"Val Accuracy : {acc:.2%}")
print(f"F1 Original  : {f1_orig:.2f}")
print(f"F1 Recaptured: {f1_recp:.2f}")
print(f"Original     : {cm[0,0]}/{cm[0].sum()}")
print(f"Recaptured   : {cm[1,1]}/{cm[1].sum()}")
print("="*60)

# ---------- 8. SAVE MODEL + TFLite ----------
model.save(f"{RESULTS_DIR}/final_model.keras")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite = converter.convert()
with open(f"{RESULTS_DIR}/recapture_detector.tflite", 'wb') as f:
    f.write(tflite)

print(f"TFLite saved: {RESULTS_DIR}/recapture_detector.tflite")
# Out:
# Mounted at /content/drive
# Linking 3 devices …
# TRAIN → Original 1151 | Recaptured 1146
# VAL   → Original 288 | Recaptured 287
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Starting training (oversample Original)…
# Epoch 1/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - Precision: 0.4992 - Recall: 0.4496 - accuracy: 0.8642 - loss: 0.3580
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/model_checkpoint.py:302: UserWarning: Can save best model only with val_f1_original available.
#   if self._should_save_model(epoch, batch, logs, filepath):
#  — val_f1_original: 0.6866
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1191s 3s/step - Precision: 0.4999 - Recall: 0.4505 - accuracy: 0.8641 - loss: 0.3579 - val_Precision: 0.9630 - val_Recall: 0.0906 - val_accuracy: 0.5443 - val_loss: 2.3843 - val_f1_original: 0.6866
# Epoch 2/30
#  73/250 ━━━━━━━━━━━━━━━━━━━━ 7:14 2s/step - Precision: 0.7255 - Recall: 0.7315 - accuracy: 0.8676 - loss: 0.3365
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/model_checkpoint.py:302: UserWarning: Can save best model only with val_f1_original available.
#   if self._should_save_model(epoch, batch, logs, filepath):
#  — val_f1_original: 0.8600
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 308s 1s/step - Precision: 0.7361 - Recall: 0.7289 - accuracy: 0.8671 - loss: 0.3134 - val_Precision: 0.8945 - val_Recall: 0.7979 - val_accuracy: 0.8522 - val_loss: 0.4165 - val_f1_original: 0.8600
# Epoch 3/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - Precision: 0.6861 - Recall: 0.7082 - accuracy: 0.9185 - loss: 0.2122
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/model_checkpoint.py:302: UserWarning: Can save best model only with val_f1_original available.
#   if self._should_save_model(epoch, batch, logs, filepath):
#  — val_f1_original: 0.8348
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1077s 3s/step - Precision: 0.6865 - Recall: 0.7085 - accuracy: 0.9185 - loss: 0.2122 - val_Precision: 0.8233 - val_Recall: 0.8606 - val_accuracy: 0.8383 - val_loss: 0.6115 - val_f1_original: 0.8348
# Epoch 4/30
#  73/250 ━━━━━━━━━━━━━━━━━━━━ 7:30 3s/step - Precision: 0.8096 - Recall: 0.8956 - accuracy: 0.9189 - loss: 0.2154
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/model_checkpoint.py:302: UserWarning: Can save best model only with val_f1_original available.
#   if self._should_save_model(epoch, batch, logs, filepath):
#  — val_f1_original: 0.8125
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - Precision: 0.8315 - Recall: 0.8873 - accuracy: 0.9228 - loss: 0.2094 - val_Precision: 0.9215 - val_Recall: 0.6132 - val_accuracy: 0.7809 - val_loss: 0.5967 - val_f1_original: 0.8125
# Epoch 5/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - Precision: 0.7454 - Recall: 0.7439 - accuracy: 0.9431 - loss: 0.1523
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/model_checkpoint.py:302: UserWarning: Can save best model only with val_f1_original available.
#   if self._should_save_model(epoch, batch, logs, filepath):
#  — val_f1_original: 0.8023
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1040s 3s/step - Precision: 0.7459 - Recall: 0.7443 - accuracy: 0.9431 - loss: 0.1523 - val_Precision: 0.9412 - val_Recall: 0.5575 - val_accuracy: 0.7617 - val_loss: 0.6721 - val_f1_original: 0.8023
# Epoch 6/30
#  73/250 ━━━━━━━━━━━━━━━━━━━━ 7:42 3s/step - Precision: 0.8463 - Recall: 0.7744 - accuracy: 0.9077 - loss: 0.2047
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/model_checkpoint.py:302: UserWarning: Can save best model only with val_f1_original available.
#   if self._should_save_model(epoch, batch, logs, filepath):
#  — val_f1_original: 0.8379
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 332s 1s/step - Precision: 0.8276 - Recall: 0.7782 - accuracy: 0.9050 - loss: 0.2142 - val_Precision: 0.9330 - val_Recall: 0.6794 - val_accuracy: 0.8157 - val_loss: 0.5737 - val_f1_original: 0.8379
# Epoch 7/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - Precision: 0.8007 - Recall: 0.8387 - accuracy: 0.9520 - loss: 0.1315
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/model_checkpoint.py:302: UserWarning: Can save best model only with val_f1_original available.
#   if self._should_save_model(epoch, batch, logs, filepath):
#  — val_f1_original: 0.8322
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1078s 3s/step - Precision: 0.8010 - Recall: 0.8388 - accuracy: 0.9520 - loss: 0.1315 - val_Precision: 0.8627 - val_Recall: 0.7666 - val_accuracy: 0.8226 - val_loss: 0.3829 - val_f1_original: 0.8322
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
#
# ============================================================
# FINAL RESULTS (2 dp)
# Val Accuracy : 85.22%
# F1 Original  : 0.86
# F1 Recaptured: 0.84
# Original     : 261/288
# Recaptured   : 229/287
# ============================================================
# Saved artifact at '/tmp/tmpit5ari09'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   138848177467664: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   138848177469584: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   138848223884880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848223883920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848223885072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848223886800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848223884496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179241232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179243536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179243728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179241424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179242768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179242576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179244688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179243152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179244880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179242000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179242384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179243920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179245264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179246224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179244496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179246032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179246800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179242960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179245456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179247184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179246608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179247952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179245648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179247376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179248336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179248912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179247568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179249104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179246416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179247760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179250064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179249680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179250640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179249872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179248144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179250448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179251024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179251600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179250832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179248528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179251408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179251984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179252560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179251792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179252944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179249296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179252368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179252752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179251216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179253520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179252176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179254288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179254480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179253904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179253136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179254864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179255440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179254096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179253712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179255248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179255824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179256400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179255632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179254672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179253328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179255056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179250256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179256208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179256784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179256016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179256592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179256976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179733904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179734096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179257168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179732944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179732560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179732752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179733328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179734672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179735248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179734480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179735632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179733520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179735056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179735440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179734288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179736208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179734864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179736976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179737168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179736592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179735824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179737552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179738128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179736784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179736400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179737936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179738512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179739088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179738320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179739472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179737360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179738896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179739280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179737744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179740048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179738704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179740816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179736016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179740240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179740624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179741200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179741776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179741008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179740432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179741584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179742160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179742736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179741968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179743120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179739856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179742544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179742928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179741392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179743696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179742352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179744464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179744656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179744080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179743312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179745040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179745616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179744272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179743888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179745424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179746000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179746576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179745808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179746960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179744848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179746384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179746768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179745232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179747536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179746192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179748304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179748496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179747344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179739664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179747920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179748112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179747152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178455184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178454800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179748688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848179747728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178454608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178456528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178455568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178455952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178456336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178454992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178457104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178455760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178457872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178455376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178457296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178457680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178458256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178458832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178458064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178457488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178458640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178459216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178459792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178459024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178460176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178456912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178459600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178459984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178458448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178460752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178459408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178461520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178461712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178461136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178460368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178462096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178462672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178461328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178460944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178462480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178463056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178463632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178462864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178464016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178461904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178463440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178463824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178462288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178464592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178463248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178465360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178465552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178464976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178464208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178466512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178465168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178464784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178466320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178466896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178467472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178466704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178467856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178465744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178467280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178467664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178466128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178468432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178467088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178469200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178464400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178468624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178469008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178469584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178470160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178469392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178469968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178468048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178468240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178469776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178470544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178470736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178468816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178456720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848178470352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177456720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177456912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177456144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177455568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177457296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177455760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177457104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177457680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177458256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177455952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177455184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177458064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177458640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177459216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177458448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177459600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177457488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177459024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177459408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177457872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177460176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177458832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177460944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177461136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177460560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177459792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177461520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177462096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177460752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177460368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177461904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177462480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177463056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177462288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177463440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177461328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177462864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177463248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177461712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177464016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177462672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177464784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177464400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177464592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177456336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177465552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177466128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177463632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177459984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177466512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177467088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177466320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177467472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177465360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177466896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177467280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177465744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177468048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177466704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177468816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177465168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177468240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177468624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177469200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177469776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848223885840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848223877584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177469392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138848177471312: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite saved: /content/drive/MyDrive/Merged_Model/results_final/recapture_detector.tflite
