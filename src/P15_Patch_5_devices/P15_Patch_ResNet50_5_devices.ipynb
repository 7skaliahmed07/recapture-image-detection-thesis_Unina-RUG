# %%
import os
import shutil
from google.colab import drive

# Remove existing directory if it exists
mount_point = '/content/drive'
if os.path.exists(mount_point):
    shutil.rmtree(mount_point)

# Create fresh directory
os.makedirs(mount_point)

# Now mount
drive.mount('/content/drive')

# !pip install pyheif
# Out:
# Mounted at /content/drive
# Collecting pyheif
#   Downloading pyheif-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pyheif) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.0->pyheif) (2.23)
# Downloading pyheif-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 79.4 MB/s eta 0:00:00
# Installing collected packages: pyheif
# Successfully installed pyheif-0.8.0

# %%
"""
Recapture Detector (ResNet50) — Patch-based training (Fully fixed & complete)
Experiment 15 | Patch-based for local pattern detection | All outputs saved
Adapted for Mobile Devices dataset under Devices folder with subfolders for each device
Key fixes:
- Consistent shapes (224x224 for train/val during training)
- Multi-patch inference on hold-out test set for better accuracy
- All required files saved: confusion matrices (png + csv), reports, curves, history csv, TFLite, summary
- Prints number of images processed at key steps
- Duration printed
"""

# Step 1: Imports
import os
import json
import random
import hashlib
import time
import sys
from pathlib import Path
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import applications, layers, models, callbacks
from PIL import Image
import pyheif
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight

# Step 2: Settings & Hyperparameters
EXPERIMENT = 15
DATA_ROOT = "/content/drive/MyDrive/Devices"
MERGED = "/content/merged_mobile_devices"
OUTPUT_DIR = "/content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results"
SPLIT_DIR = "/content/drive/MyDrive/Recapture_Photo_Detection"
IMG_SIZE = 224
LARGE_SIZE = 256
BATCH_SIZE = 16
EPOCHS = 8
LEARNING_RATE = 1e-4
N_FOLDS = 5
MODEL_NAME = "Resnet50"
PREPROCESSING = "none"
DROPOUT_RATE = 0.4
SEED = 42
TRAIN_FRAC, TEST_FRAC = 0.85, 0.15
REPEAT_FACTOR = 4
NUM_TEST_PATCHES = 5
DEVICES = ["Iphone-11","Iphone-16", "Nothing_2a", "Pixel","Poco-M3"]

HYPERPARAMETERS = {
    "learning_rate": LEARNING_RATE,
    "batch_size": BATCH_SIZE,
    "optimizer": "Adam",
    "epochs": EPOCHS,
    "n_folds": N_FOLDS,
    "dropout_rate": DROPOUT_RATE,
    "large_size": LARGE_SIZE,
    "repeat_factor": REPEAT_FACTOR,
    "num_test_patches": NUM_TEST_PATCHES
}

# Step 3: Create directories
for p in [OUTPUT_DIR, f"{OUTPUT_DIR}/checkpoints", MERGED, SPLIT_DIR]:
    Path(p).mkdir(parents=True, exist_ok=True)

# Step 4: Image conversion utilities
def ensure_jpg_from_path(src_path: Path, dst_path: Path, quality=95):
    dst_path.parent.mkdir(parents=True, exist_ok=True)
    if dst_path.exists():
        return
    sfx = src_path.suffix.lower()
    try:
        if sfx in {".heic", ".heif"}:
            heif_file = pyheif.read(str(src_path))
            img = Image.frombytes(heif_file.mode, heif_file.size, heif_file.data,
                                  "raw", heif_file.mode, heif_file.stride)
            img = img.convert("RGB")
            img.save(dst_path, "JPEG", quality=quality)
        else:
            img = Image.open(src_path).convert("RGB")
            img.save(dst_path, "JPEG", quality=quality)
    except Exception as e:
        print(f"[WARN] Failed converting {src_path}: {e}")

def copy_or_convert(src_folder, dst_folder, prefix=""):
    cnt = 0
    src = Path(src_folder)
    if not src.exists():
        return 0
    for f in src.rglob("*.*"):
        if f.suffix.lower() in {".jpg",".jpeg",".png",".heic",".heif"}:
            name = f"{prefix}_{f.name}".rsplit(".",1)[0] + ".jpg"
            dst = Path(dst_folder) / name
            ensure_jpg_from_path(f, dst)
            cnt += 1
    return cnt

# Step 5: Merge & convert images from multiple devices
print("\n--- MERGING & CONVERTING ---")
os.makedirs(f"{MERGED}/originals", exist_ok=True)
os.makedirs(f"{MERGED}/recaptures", exist_ok=True)
total_orig_cnt = 0
total_recap_cnt = 0
for dev in DEVICES:
    orig_cnt = copy_or_convert(f"{DATA_ROOT}/{dev}/originals", f"{MERGED}/originals", dev.lower())
    recap_cnt = copy_or_convert(f"{DATA_ROOT}/{dev}/recaptures", f"{MERGED}/recaptures", dev.lower())
    total_orig_cnt += orig_cnt
    total_recap_cnt += recap_cnt
print(f"Converted originals: {total_orig_cnt} | recaptures: {total_recap_cnt}")

if total_orig_cnt + total_recap_cnt == 0:
    print("[ERROR] No images found or converted. Stopping pipeline.")
    sys.exit(1)

# Step 6: Collect paths
def get_paths(folder):
    return sorted([str(p) for p in Path(folder).glob("*.jpg")])

orig_paths = get_paths(f"{MERGED}/originals")
recap_paths = get_paths(f"{MERGED}/recaptures")
print(f"Final - Originals: {len(orig_paths)} | Recaptures: {len(recap_paths)}")

if len(orig_paths) + len(recap_paths) == 0:
    print("[ERROR] No JPG images after conversion. Stopping.")
    sys.exit(1)

print(f"[INFO] No. images processed (converted to JPG): Originals {len(orig_paths)}, Recaptures {len(recap_paths)}, Total {len(orig_paths)+len(recap_paths)}")

# Step 7: Shuffle and split
np.random.seed(SEED)
random.seed(SEED)
np.random.shuffle(orig_paths)
np.random.shuffle(recap_paths)

def split_list(lst, train_frac):
    n = len(lst)
    if n == 0:
        return [], []
    n_train = int(np.floor(train_frac * n))
    return lst[:n_train], lst[n_train:]

train_o, test_o = split_list(orig_paths, TRAIN_FRAC)
train_r, test_r = split_list(recap_paths, TRAIN_FRAC)

train_paths = train_o + train_r
test_paths = test_o + test_r
train_labels = [0] * len(train_o) + [1] * len(train_r)
test_labels = [0] * len(test_o) + [1] * len(test_r)

print(f"TRAIN → Original: {len(train_o)} | Recapture: {len(train_r)} | Total: {len(train_paths)}")
print(f"TEST  → Original: {len(test_o)} | Recapture: {len(test_r)} | Total: {len(test_paths)}")

if len(train_paths) == 0:
    print("[ERROR] No training images after split. Stopping.")
    sys.exit(1)

print(f"[INFO] Train images: {len(train_paths)} | Test images: {len(test_paths)}")

# Step 8: Assurance checks
assert len(set(train_paths) & set(test_paths)) == 0, "Overlap detected!"
print("No train/test overlap — GOOD.")

# Save split hashes
def path_hash(p): return hashlib.md5(p.encode()).hexdigest()
split_hashes = {
    'train_hashes': [path_hash(p) for p in sorted(train_paths)],
    'test_hashes': [path_hash(p) for p in sorted(test_paths)]
}
with open(f"{SPLIT_DIR}/split_hashes.json","w") as f:
    json.dump(split_hashes, f, indent=2)

# Step 9: Dataset characteristics
def device_count(paths):
    counts = {}
    for p in paths:
        stem = Path(p).stem
        device = stem.split('_')[0] if '_' in stem else 'unknown'
        counts[device] = counts.get(device, 0) + 1
    return counts

dataset_info = {
    'total_originals': len(orig_paths),
    'total_recaptures': len(recap_paths),
    'total_images': len(orig_paths)+len(recap_paths),
    'per_device_originals': device_count(orig_paths),
    'per_device_recaptures': device_count(recap_paths),
    'splits': {
        'train': {'originals': len(train_o), 'recaptures': len(train_r)},
        'test': {'originals': len(test_o), 'recaptures': len(test_r)}
    }
}
with open(f"{OUTPUT_DIR}/dataset_characteristics.json","w") as f:
    json.dump(dataset_info, f, indent=2)
pd.DataFrame([dataset_info]).to_csv(f"{OUTPUT_DIR}/dataset_characteristics.csv", index=False)
print("Saved dataset characteristics.")

# Step 10: Pipeline summary
pipeline_summary = {
    'experiment': f"Experiment - {EXPERIMENT}",
    'seed': SEED,
    'img_size': IMG_SIZE,
    'batch_size': BATCH_SIZE,
    'repeat_factor': REPEAT_FACTOR,
    'augmentation': ['random_flip_left_right','random_brightness(0.1)','random_contrast(0.9,1.1)'],
    'preprocessing': PREPROCESSING,
    'model': 'ResNet50(include_top=False) + GAP + Dropout(0.4) + Dense(128,relu) + Dense(1,sigmoid)',
    'optimizer': f'Adam({LEARNING_RATE})',
    'loss': 'binary_crossentropy',
    'metrics': ['accuracy'],
    'split': {'train_frac': TRAIN_FRAC, 'test_frac': TEST_FRAC},
    'hyperparameters': HYPERPARAMETERS
}
with open(f"{OUTPUT_DIR}/pipeline_summary.json","w") as f:
    json.dump(pipeline_summary, f, indent=2)
with open(f"{OUTPUT_DIR}/README_pipeline.md","w") as f:
    f.write("# Pipeline Summary\n\n")
    for k,v in pipeline_summary.items():
        f.write(f"- **{k}**: {v}\n")
print("Saved pipeline summary.")

# Step 11: TF Dataset helpers
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

def decode_and_resize(path, resize_size=LARGE_SIZE):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (resize_size, resize_size))
    return img

def augment(img):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, 0.1)
    img = tf.image.random_contrast(img, 0.9, 1.1)
    return img

@tf.function
def process_train(path_tensor, label):
    img = decode_and_resize(path_tensor)
    if tf.random.uniform(()) < 0.7:
        img = augment(img)
    img = tf.image.random_crop(img, (IMG_SIZE, IMG_SIZE, 3))
    img = tf.keras.applications.resnet50.preprocess_input(img)
    return img, label

@tf.function
def process_val_test(path_tensor, label):
    img = decode_and_resize(path_tensor)
    offset = (LARGE_SIZE - IMG_SIZE) // 2
    img = tf.image.crop_to_bounding_box(img, offset, offset, IMG_SIZE, IMG_SIZE)
    img = tf.keras.applications.resnet50.preprocess_input(img)
    return img, label

# Step 12: Test dataset
test_paths_tf = tf.constant(test_paths, dtype=tf.string)
test_labels_tf = tf.constant(test_labels, dtype=tf.int32)
test_ds = tf.data.Dataset.from_tensor_slices((test_paths_tf, test_labels_tf))
test_ds = test_ds.map(process_val_test, num_parallel_calls=tf.data.AUTOTUNE) \
                 .batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# Step 13: Class weights
unique_labels = np.unique(train_labels)
if len(unique_labels) == 1:
    print(f"[INFO] Only one class found. Using uniform weight.")
    class_weight_dict = {int(unique_labels[0]): 1.0}
else:
    weights = compute_class_weight('balanced', classes=unique_labels, y=train_labels)
    class_weight_dict = {int(k): float(v) for k, v in zip(unique_labels, weights)}
print(f"Class weights: {class_weight_dict}")

# Step 14: Cross-validation training
print("\n--- STARTING 5-FOLD CROSS-VALIDATION ---")
start_time = time.time()

EXPERIMENT_NAME = f"exp_{EXPERIMENT}_{MODEL_NAME}_patch"
skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=SEED)
fold_results = []
best_val_acc = 0.0
best_fold = 0
best_model = None

train_paths_np = np.array(train_paths)
train_labels_np = np.array(train_labels)

for fold_no, (subtrain_idx, val_idx) in enumerate(skf.split(train_paths_np, train_labels_np), 1):
    print(f"\n=== Fold {fold_no}/{N_FOLDS} ===")
    subtrain_paths = train_paths_np[subtrain_idx].tolist()
    subtrain_labels = train_labels_np[subtrain_idx].tolist()
    val_paths = train_paths_np[val_idx].tolist()
    val_labels = train_labels_np[val_idx].tolist()

    print(f"[INFO] Fold {fold_no} - Subtrain images: {len(subtrain_paths)} | Val images: {len(val_paths)}")

    # Training dataset
    train_ds = tf.data.Dataset.from_tensor_slices((tf.constant(subtrain_paths), tf.constant(subtrain_labels)))
    train_ds = train_ds.repeat(REPEAT_FACTOR) \
                       .shuffle(buffer_size=8000, seed=SEED, reshuffle_each_iteration=True) \
                       .map(process_train, num_parallel_calls=tf.data.AUTOTUNE) \
                       .batch(BATCH_SIZE) \
                       .prefetch(tf.data.AUTOTUNE)

    # Validation dataset (for fit)
    val_ds = tf.data.Dataset.from_tensor_slices((tf.constant(val_paths), tf.constant(val_labels)))
    val_ds = val_ds.map(process_val_test, num_parallel_calls=tf.data.AUTOTUNE) \
                   .batch(BATCH_SIZE) \
                   .prefetch(tf.data.AUTOTUNE)

    # Model
    base = applications.ResNet50(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
    base.trainable = True
    inputs = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(DROPOUT_RATE)(x)
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    model = models.Model(inputs, outputs)

    model.compile(optimizer=tf.keras.optimizers.Adam(LEARNING_RATE),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # Callbacks
    ckpt_path = f"{OUTPUT_DIR}/checkpoints/{EXPERIMENT_NAME}_fold{fold_no}.weights.h5"
    cp = callbacks.ModelCheckpoint(ckpt_path, save_best_only=True, save_weights_only=True,
                                   monitor='val_accuracy', mode='max', verbose=1)
    es = callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, verbose=1)
    lr_reduce = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

    if Path(ckpt_path).exists():
        print("Resuming from existing checkpoint...")
        model.load_weights(ckpt_path)

    # Train
    steps_per_epoch = max(1, (len(subtrain_paths) * REPEAT_FACTOR) // BATCH_SIZE)
    history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS,
                        steps_per_epoch=steps_per_epoch,
                        callbacks=[cp, es, lr_reduce],
                        class_weight=class_weight_dict,
                        verbose=1)

    # Save history CSV
    hist_df = pd.DataFrame(history.history)
    hist_df.to_csv(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_history.csv", index=False)

    # Save loss curves PNG
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss Curve'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.grid(True)
    plt.subplot(1,2,2)
    plt.plot(history.history['accuracy'], label='Train Acc')
    plt.plot(history.history['val_accuracy'], label='Val Acc')
    plt.title('Accuracy Curve'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.grid(True)
    plt.savefig(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_learning_curve.png", dpi=300, bbox_inches='tight')
    plt.close()
    print(f"Saved learning curves and history for fold {fold_no}.")

    # Multi-patch prediction
    def predict_multi_patch(paths, labels, model, num_patches=NUM_TEST_PATCHES):
        crops = [
            (0, 0),
            (0, LARGE_SIZE - IMG_SIZE),
            (LARGE_SIZE - IMG_SIZE, 0),
            (LARGE_SIZE - IMG_SIZE, LARGE_SIZE - IMG_SIZE),
            ((LARGE_SIZE - IMG_SIZE)//2, (LARGE_SIZE - IMG_SIZE)//2)
        ][:num_patches]
        y_true = []
        y_pred_probs = []
        for path, label in zip(paths, labels):
            img = decode_and_resize(tf.constant(path))
            img = tf.expand_dims(img, 0)
            probs = []
            for cy, cx in crops:
                patch = img[:, cy:cy+IMG_SIZE, cx:cx+IMG_SIZE, :]
                prob = float(model(patch, training=False)[0][0])
                probs.append(prob)
            avg_prob = np.mean(probs)
            y_true.append(label)
            y_pred_probs.append(avg_prob)
        y_pred = [1 if p > 0.5 else 0 for p in y_pred_probs]
        return np.array(y_true), np.array(y_pred)

    # Evaluate with multi-patch
    y_val_true, y_val_pred = predict_multi_patch(val_paths, val_labels, model)
    y_test_true, y_test_pred = predict_multi_patch(test_paths, test_labels, model)

    cm_val = confusion_matrix(y_val_true, y_val_pred)
    cm_test = confusion_matrix(y_test_true, y_test_pred)

    acc_val = round(np.sum(y_val_true == y_val_pred) / len(y_val_true), 2) if len(y_val_true) > 0 else 0.0
    acc_test = round(np.sum(y_test_true == y_test_pred) / len(y_test_true), 2) if len(y_test_true) > 0 else 0.0

    # Save confusion matrices PNG & CSV
    for split, cm, acc in [("val", cm_val, acc_val), ("test", cm_test, acc_test)]:
        plt.figure(figsize=(6,5))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                    xticklabels=['Original','Recaptured'], yticklabels=['Original','Recaptured'])
        plt.title(f"Fold {fold_no} {split.upper()} Confusion Matrix | Acc: {acc:.2f}")
        plt.savefig(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_cm_{split}.png", dpi=300, bbox_inches='tight')
        plt.close()
        pd.DataFrame(cm).to_csv(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_cm_{split}.csv", index=False)

    # Save reports CSV (rounded 2 dec)
    report_val = classification_report(y_val_true, y_val_pred, target_names=['Original','Recaptured'], output_dict=True, zero_division=0)
    report_test = classification_report(y_test_true, y_test_pred, target_names=['Original','Recaptured'], output_dict=True, zero_division=0)
    pd.DataFrame(report_val).transpose().round(2).to_csv(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_report_val.csv")
    pd.DataFrame(report_test).transpose().round(2).to_csv(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_report_test.csv")

    # Fold summary JSON
    fold_summary = {
        'fold': fold_no,
        'val_accuracy': acc_val,
        'test_accuracy': acc_test,
        'val_report': report_val,
        'test_report': report_test
    }
    with open(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_fold{fold_no}_summary.json","w") as f:
        json.dump(fold_summary, f, indent=2)

    fold_results.append(fold_summary)

    if acc_val > best_val_acc:
        best_val_acc = acc_val
        best_fold = fold_no
        best_model = model

# Step 15: Average results & save overall summary
avg_val_acc = round(np.mean([f['val_accuracy'] for f in fold_results]), 2)
avg_test_acc = round(np.mean([f['test_accuracy'] for f in fold_results]), 2)
print(f"\nAverage Validation Accuracy: {avg_val_acc:.2f} | Average Test Accuracy: {avg_test_acc:.2f}")

avg_summary = {
    'experiment': EXPERIMENT_NAME,
    'avg_val_accuracy': avg_val_acc,
    'avg_test_accuracy': avg_test_acc,
    'fold_details': fold_results
}
with open(f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_average_summary.json","w") as f:
    json.dump(avg_summary, f, indent=2)

# Step 16: Save best model & TFLite
if best_model:
    best_model_path = f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_best_fold{best_fold}.keras"
    best_model.save(best_model_path)
    print(f"Saved best model: {best_model_path}")

    converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite = converter.convert()
    tflite_path = f"{OUTPUT_DIR}/{EXPERIMENT_NAME}_detector.tflite"
    Path(tflite_path).write_bytes(tflite)
    print(f"Saved TFLite model: {tflite_path}")

# Step 17: Duration
duration = time.time() - start_time
print(f"\nTotal duration till completion: {duration:.2f} seconds ({duration/60:.2f} minutes)")

print("\nALL DONE. Results saved to:", OUTPUT_DIR)
# Out:
# --- MERGING & CONVERTING ---
# Converted originals: 408 | recaptures: 391
# Final - Originals: 408 | Recaptures: 391
# [INFO] No. images processed (converted to JPG): Originals 408, Recaptures 391, Total 799
# TRAIN → Original: 346 | Recapture: 332 | Total: 678
# TEST  → Original: 62 | Recapture: 59 | Total: 121
# [INFO] Train images: 678 | Test images: 121
# No train/test overlap — GOOD.
# Saved dataset characteristics.
# Saved pipeline summary.
# Class weights: {0: 0.9797687861271677, 1: 1.0210843373493976}
#
# --- STARTING 5-FOLD CROSS-VALIDATION ---
#
# === Fold 1/5 ===
# [INFO] Fold 1 - Subtrain images: 542 | Val images: 136
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7475 - loss: 0.4833
# Epoch 1: val_accuracy improved from -inf to 0.81618, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold1.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 310s 2s/step - accuracy: 0.7483 - loss: 0.4821 - val_accuracy: 0.8162 - val_loss: 0.6072 - learning_rate: 1.0000e-04
# Epoch 2/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 58:38 26s/step - accuracy: 1.0000 - loss: 0.0522
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy did not improve from 0.81618
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 47s 153ms/step - accuracy: 1.0000 - loss: 0.0522 - val_accuracy: 0.8015 - val_loss: 0.6117 - learning_rate: 1.0000e-04
# Epoch 3/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9644 - loss: 0.1128
# Epoch 3: val_accuracy improved from 0.81618 to 0.82353, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold1.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 250s 2s/step - accuracy: 0.9644 - loss: 0.1130 - val_accuracy: 0.8235 - val_loss: 0.7546 - learning_rate: 1.0000e-04
# Epoch 4/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - accuracy: 1.0000 - loss: 0.0405
# Epoch 4: val_accuracy did not improve from 0.82353
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 17s 124ms/step - accuracy: 1.0000 - loss: 0.0405 - val_accuracy: 0.8235 - val_loss: 0.7449 - learning_rate: 1.0000e-04
# Epoch 5/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9783 - loss: 0.0604
# Epoch 5: val_accuracy improved from 0.82353 to 0.85294, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold1.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 251s 2s/step - accuracy: 0.9783 - loss: 0.0604 - val_accuracy: 0.8529 - val_loss: 0.7918 - learning_rate: 1.0000e-04
# Epoch 6/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 19s 144ms/step - accuracy: 1.0000 - loss: 0.0242
# Epoch 6: val_accuracy did not improve from 0.85294
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 1.0000 - loss: 0.0242 - val_accuracy: 0.8456 - val_loss: 0.8036 - learning_rate: 1.0000e-04
# Epoch 7/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9890 - loss: 0.0400
# Epoch 7: val_accuracy did not improve from 0.85294
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9890 - loss: 0.0399 - val_accuracy: 0.8309 - val_loss: 0.4636 - learning_rate: 5.0000e-05
# Epoch 8/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 8: val_accuracy did not improve from 0.85294
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 14s 106ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8382 - val_loss: 0.4630 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 5.
# Saved learning curves and history for fold 1.
#
# === Fold 2/5 ===
# [INFO] Fold 2 - Subtrain images: 542 | Val images: 136
# Epoch 1/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7546 - loss: 0.4708
# Epoch 1: val_accuracy improved from -inf to 0.85294, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold2.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 296s 2s/step - accuracy: 0.7554 - loss: 0.4696 - val_accuracy: 0.8529 - val_loss: 0.5840 - learning_rate: 1.0000e-04
# Epoch 2/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 53:08 24s/step - accuracy: 0.8750 - loss: 0.2409
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy did not improve from 0.85294
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 44s 153ms/step - accuracy: 0.8750 - loss: 0.2409 - val_accuracy: 0.8382 - val_loss: 0.5496 - learning_rate: 1.0000e-04
# Epoch 3/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9537 - loss: 0.1196
# Epoch 3: val_accuracy improved from 0.85294 to 0.86765, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold2.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.9537 - loss: 0.1196 - val_accuracy: 0.8676 - val_loss: 0.5426 - learning_rate: 1.0000e-04
# Epoch 4/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 19s 142ms/step - accuracy: 1.0000 - loss: 0.0284
# Epoch 4: val_accuracy did not improve from 0.86765
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 1.0000 - loss: 0.0284 - val_accuracy: 0.8676 - val_loss: 0.5415 - learning_rate: 1.0000e-04
# Epoch 5/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9656 - loss: 0.1118
# Epoch 5: val_accuracy did not improve from 0.86765
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 290s 2s/step - accuracy: 0.9656 - loss: 0.1117 - val_accuracy: 0.8676 - val_loss: 0.5406 - learning_rate: 1.0000e-04
# Epoch 6/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - accuracy: 1.0000 - loss: 0.0138
# Epoch 6: val_accuracy did not improve from 0.86765
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.8676 - val_loss: 0.5506 - learning_rate: 1.0000e-04
# Epoch 7/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9812 - loss: 0.0655
# Epoch 7: val_accuracy did not improve from 0.86765
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9812 - loss: 0.0655 - val_accuracy: 0.8235 - val_loss: 0.5551 - learning_rate: 1.0000e-04
# Epoch 8/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 19s 144ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 8: val_accuracy did not improve from 0.86765
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8162 - val_loss: 0.5468 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 3.
# Saved learning curves and history for fold 2.
#
# === Fold 3/5 ===
# [INFO] Fold 3 - Subtrain images: 542 | Val images: 136
# Epoch 1/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7540 - loss: 0.4756
# Epoch 1: val_accuracy improved from -inf to 0.83824, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold3.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 298s 2s/step - accuracy: 0.7548 - loss: 0.4744 - val_accuracy: 0.8382 - val_loss: 0.6006 - learning_rate: 1.0000e-04
# Epoch 2/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 55:37 25s/step - accuracy: 1.0000 - loss: 0.1887
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy improved from 0.83824 to 0.84559, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold3.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 47s 162ms/step - accuracy: 1.0000 - loss: 0.1887 - val_accuracy: 0.8456 - val_loss: 0.6121 - learning_rate: 1.0000e-04
# Epoch 3/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9547 - loss: 0.1231
# Epoch 3: val_accuracy did not improve from 0.84559
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9546 - loss: 0.1232 - val_accuracy: 0.8162 - val_loss: 0.6139 - learning_rate: 1.0000e-04
# Epoch 4/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 19s 144ms/step - accuracy: 1.0000 - loss: 0.0181
# Epoch 4: val_accuracy did not improve from 0.84559
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 1.0000 - loss: 0.0181 - val_accuracy: 0.8235 - val_loss: 0.6131 - learning_rate: 1.0000e-04
# Epoch 5/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9712 - loss: 0.0813
# Epoch 5: val_accuracy did not improve from 0.84559
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 241s 2s/step - accuracy: 0.9712 - loss: 0.0813 - val_accuracy: 0.8382 - val_loss: 1.3512 - learning_rate: 1.0000e-04
# Epoch 6/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 19s 145ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 6: val_accuracy did not improve from 0.84559
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 14s 107ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8456 - val_loss: 1.3563 - learning_rate: 1.0000e-04
# Epoch 7/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9860 - loss: 0.0421
# Epoch 7: val_accuracy improved from 0.84559 to 0.87500, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold3.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.9860 - loss: 0.0421 - val_accuracy: 0.8750 - val_loss: 0.7786 - learning_rate: 5.0000e-05
# Epoch 8/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 20s 150ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 8: val_accuracy did not improve from 0.87500
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8750 - val_loss: 0.7954 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 7.
# Saved learning curves and history for fold 3.
#
# === Fold 4/5 ===
# [INFO] Fold 4 - Subtrain images: 543 | Val images: 135
# Epoch 1/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7725 - loss: 0.4684
# Epoch 1: val_accuracy improved from -inf to 0.75556, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold4.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 320s 2s/step - accuracy: 0.7731 - loss: 0.4674 - val_accuracy: 0.7556 - val_loss: 0.9138 - learning_rate: 1.0000e-04
# Epoch 2/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 59:45 27s/step - accuracy: 0.7500 - loss: 0.5699
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy did not improve from 0.75556
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 47s 154ms/step - accuracy: 0.7500 - loss: 0.5699 - val_accuracy: 0.7407 - val_loss: 0.9599 - learning_rate: 1.0000e-04
# Epoch 3/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9565 - loss: 0.1236
# Epoch 3: val_accuracy improved from 0.75556 to 0.80741, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold4.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 312s 2s/step - accuracy: 0.9565 - loss: 0.1235 - val_accuracy: 0.8074 - val_loss: 0.6872 - learning_rate: 1.0000e-04
# Epoch 4/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 24s 183ms/step - accuracy: 1.0000 - loss: 0.1243
# Epoch 4: val_accuracy did not improve from 0.80741
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 18s 134ms/step - accuracy: 1.0000 - loss: 0.1243 - val_accuracy: 0.8000 - val_loss: 0.6685 - learning_rate: 1.0000e-04
# Epoch 5/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9599 - loss: 0.1368
# Epoch 5: val_accuracy improved from 0.80741 to 0.82222, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold4.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 276s 2s/step - accuracy: 0.9599 - loss: 0.1367 - val_accuracy: 0.8222 - val_loss: 0.5006 - learning_rate: 1.0000e-04
# Epoch 6/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 24s 182ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 6: val_accuracy improved from 0.82222 to 0.82963, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold4.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 23s 173ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.8296 - val_loss: 0.5065 - learning_rate: 1.0000e-04
# Epoch 7/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9825 - loss: 0.0483
# Epoch 7: val_accuracy improved from 0.82963 to 0.86667, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold4.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 284s 2s/step - accuracy: 0.9825 - loss: 0.0483 - val_accuracy: 0.8667 - val_loss: 0.4981 - learning_rate: 1.0000e-04
# Epoch 8/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 24s 180ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 8: val_accuracy did not improve from 0.86667
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 17s 128ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8667 - val_loss: 0.4818 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 7.
# Saved learning curves and history for fold 4.
#
# === Fold 5/5 ===
# [INFO] Fold 5 - Subtrain images: 543 | Val images: 135
# Epoch 1/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7387 - loss: 0.4873
# Epoch 1: val_accuracy improved from -inf to 0.83704, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold5.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 324s 2s/step - accuracy: 0.7394 - loss: 0.4862 - val_accuracy: 0.8370 - val_loss: 0.6778 - learning_rate: 1.0000e-04
# Epoch 2/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 52:53 24s/step - accuracy: 1.0000 - loss: 0.1153
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy did not improve from 0.83704
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 39s 112ms/step - accuracy: 1.0000 - loss: 0.1153 - val_accuracy: 0.8370 - val_loss: 0.6907 - learning_rate: 1.0000e-04
# Epoch 3/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9583 - loss: 0.1187
# Epoch 3: val_accuracy improved from 0.83704 to 0.90370, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold5.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 276s 2s/step - accuracy: 0.9583 - loss: 0.1187 - val_accuracy: 0.9037 - val_loss: 0.4117 - learning_rate: 1.0000e-04
# Epoch 4/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 25s 191ms/step - accuracy: 1.0000 - loss: 0.0260
# Epoch 4: val_accuracy did not improve from 0.90370
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 0.9037 - val_loss: 0.4145 - learning_rate: 1.0000e-04
# Epoch 5/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9634 - loss: 0.1200
# Epoch 5: val_accuracy improved from 0.90370 to 0.91111, saving model to /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/checkpoints/exp_14_Resnet50_patch_fold5.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 281s 2s/step - accuracy: 0.9634 - loss: 0.1199 - val_accuracy: 0.9111 - val_loss: 0.3091 - learning_rate: 1.0000e-04
# Epoch 6/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 23s 179ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 6: val_accuracy did not improve from 0.91111
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 17s 127ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8889 - val_loss: 0.3222 - learning_rate: 1.0000e-04
# Epoch 7/8
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9697 - loss: 0.0923
# Epoch 7: val_accuracy did not improve from 0.91111
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 261s 2s/step - accuracy: 0.9697 - loss: 0.0923 - val_accuracy: 0.8370 - val_loss: 0.7941 - learning_rate: 1.0000e-04
# Epoch 8/8
#   1/135 ━━━━━━━━━━━━━━━━━━━━ 23s 179ms/step - accuracy: 0.9167 - loss: 0.1526
# Epoch 8: val_accuracy did not improve from 0.91111
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.9167 - loss: 0.1526 - val_accuracy: 0.8444 - val_loss: 0.7959 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 5.
# Saved learning curves and history for fold 5.
#
# Average Validation Accuracy: 0.76 | Average Test Accuracy: 0.78
# Saved best model: /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/exp_14_Resnet50_patch_best_fold5.keras
# Saved artifact at '/tmp/tmphkaatvq3'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_899')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   139736656065744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139737505036240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139737523764112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757411792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139740677064464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139737505026256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757409104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757405456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757406224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757404496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757410448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757402576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757411216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757405840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139737058497488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757406992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757407760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757404112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757406800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757406032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757411024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757407184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757403920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757409680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757408720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757408144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757405648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757407568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757402768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757411984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757407376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757409488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757410640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757403152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757411600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757403536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757405072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757404688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757408528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757403728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757409872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757402960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757409296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757412176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757406608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757406416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757407952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757410064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757405264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757410256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646880208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646881168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757404880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139739757396240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646880976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646880400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646879824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646882320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646882128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646880016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646881936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646881360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646880592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646883472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646883280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646881552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646884240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646883664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646881744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646885776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646885584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646883856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646885392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646884816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646882896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646886928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646886736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646885008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646886544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646885968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646883088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646882512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646880784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646884624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646884432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646882704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646884048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646888080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646887888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646886160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646887696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646887120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646885200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646889232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646889040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646887312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646888848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646888272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646886352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646890384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646890192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646888464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646890000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646889424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646887504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646891536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646891344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646889616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646891152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646890576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646888656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646892688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646892496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646890768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646892304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646891728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646889808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646893840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646893648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646891920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646893456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646892880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646890960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646894992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646894800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646893072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646894608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646894032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646895376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646895568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646895952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646894224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646894416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646892112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646893264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645635600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646895184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735646895760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645635792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645635216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645634640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645636944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645636752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645634832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645637712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645637136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645635984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645639248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645639056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645637328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645638864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645638288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645636368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645640400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645640208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645638480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645640016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645639440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645636560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645635024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645635408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645638096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645637904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645636176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645637520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645641552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645641360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645639632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645641168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645640592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645638672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645642704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645642512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645640784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645642320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645641744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645639824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645643856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645643664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645641936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645643472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645642896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645640976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645645008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645644816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645643088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645644624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645644048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645642128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645646160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645645968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645644240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645645776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645645200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645643280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645647312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645647120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645645392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645646928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645646352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645644432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645648464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645648272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645646544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645648080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645647504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645645584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645649616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645649424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645647696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645649232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645648656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645646736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645650384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645650576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645648848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645650768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645647888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645649808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645650192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645649040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645650000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644340496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644341072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644341456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644342416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644342224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644341648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644342032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644341264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644340880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644343568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644343376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644340688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644343184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644342608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644340304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644344720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644344528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644342800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644344336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644343760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644341840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644345872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644345680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644343952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644345488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644344912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644342992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644347024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644346832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644345104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644346640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644346064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644344144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644348176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644347984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644346256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644348944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644348368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644346448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644350480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644350288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644348560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644350096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644349520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644347600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644351632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644351440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644349712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644351248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644350672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644347792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644347216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644345296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644349328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644349136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644347408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644348752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644352784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644352592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644350864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644352400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644351824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644349904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644353936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644353744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644352016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644353552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644352976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644351056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644355088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644354896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644353168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644354704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644354128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644352208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644356240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644356048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644354320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644355856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644355472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644353360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644356432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644354512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644355664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735644355280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645144080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645144848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645145040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645143504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645144656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645144272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645143696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645143120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645146192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645146000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645143312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645146576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645146384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645147152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139735645143888: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved TFLite model: /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results/exp_14_Resnet50_patch_detector.tflite
#
# Total duration till completion: 7878.59 seconds (131.31 minutes)
#
# ALL DONE. Results saved to: /content/drive/MyDrive/Recapture_Photo_Detection/Resnet50_MobileDevices/results
